# %% [markdown]
# Tessellated Fracture Workbook

# %%
from pathlib import Path
from pyfracman.fab import *

# %%
data_dir = Path(r"C:\Users\scott.mckean\Desktop\Data Exports")

# %%
f_name = next(data_dir.rglob("test_tessellated_frac.fab"))

# %%
output = parse_fab_file(f_name)

# %%
output['t_nodes']
# Out:
# [array([[1597.941022 , 1602.8491   , 1602.8491   , 1593.9182   ,
#          1593.9182   , 1595.05     , 1588.782441 , 1584.9873   ,
#          1584.9873   , 1579.602372 , 1576.0564   , 1576.0564   ,
#          1576.935917 , 1570.405642 , 1567.1255   , 1567.1255   ,
#          1570.05     , 1561.161496 , 1558.1946   , 1558.1946   ,
#          1551.903956 , 1556.398488 , 1549.2637   , 1549.2637   ,
#          1542.626812 , 1545.05     , 1540.3328   , 1540.3328   ,
#          1533.329512 , 1531.4019   , 1531.4019   , 1531.693263 ,
#          1524.022359 , 1522.4711   , 1522.4711   , 1514.736167 ,
#          1520.05     , 1513.5402   , 1513.5402   , 1602.8491   ,
#          1593.9182   , 1584.9873   , 1576.0564   , 1567.1255   ,
#          1558.1946   , 1549.2637   , 1540.3328   , 1531.4019   ,
#          1522.4711   , 1513.5402   , 1602.8491   , 1593.9182   ,
#          1584.9873   , 1576.0564   , 1567.1255   , 1558.1946   ,
# ...
